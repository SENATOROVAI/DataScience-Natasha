# %%
"""Глава 1."""
# Out:
# 'Глава 1.'

# %% [markdown]
# ### 1.1 Введение в Data Science
#
# Цифровая революция
#
# **Data Science** - научная дисциплина, которая включает в себя извлечение информациииз огромных объемов данных с использованием различных научных методов, алгоритмов  и процессов. Она помогает обнаруживать в необработанных данных скрытые закономерности.
#
# **Data Science** - это междисциплинарная область, которая помогает нам извлекать знания из структурированных и неструктурированных данных.
#
# #### 1.1.1 Зачем нам Data Science?
#
# **Задачи Data Science**
#
# 1. задавать правильные вопросы
# 2. находить основную причину проблемы
# 3. находить закономерности среди, на первый взгляд, хаотичных необработанных данных
# 4. создавать модели для предиктивного анализа
# 5. визуализировать и отображать результаты с помощью графиков, информационных панелей
# 6. наделять машины интеллектом
# 7. определять лояльность клиентов с помощью анализа настроений
# 8. принимать более качественные и быстрые решения
# 9. рекомендовать правильный продукт нужному клиенту для развития бизнеса
#
# #### 1.1.2 История Data Science
#
# **_Данные в древности_**
#
# 1. Около 18 000 г. до н. э.  - палеолиетические племена делали зарубки на палках и костях для торговой деятельности
# 2. Около 2400 г. до н. э.  - счеты, первые библиотеки
#
# **_Появление статистики_**
#
# 1. 1663 г.  - Джон Граунт провел первый зарегестрированный эксперимент по статистическому анализу данных
# 2. 1865 г.  - Ричард Миллард Девенс ввел термин бизнес-аналитика в "Энциклопедии коммерческих  и деловых анекдотов"
# 3. 1889 г.  - Герман Холлерит создал Табулирующую машину Холлерита
#
# **_Зарождение современного хранения данных_**
#
#  1. 1926 г. - Никола Тесла: превращение планеты в огромный мозг при помощи прибора размером с карман жилета
#  2. 1928 г.  - Фриц Пфлеумер изобрел метод магнитного хранения информации на ленте
#
#  **_Появление первых больших центров обработки данных_**
#
# 1. 1965 г.  - план США по созданию первого в мире центра по обработке данных
#
# **_Появление Интернета_**
#
# 1. 1991 г.  - Тим Бернерс-Ли объявил о рождении Интернета
# 2. 1997 г.  - Google Search
# 3. 2000 г. Python 2.0
# 4. 2010 г.  - Эрик Шмидт, главный исполнительный директор Goggle: каждые 2 дня создается столько же данных, сколько было создано человечеством с начала цивилизации до 2003 г.
# 5. 2011 г. - отчет McKinsey: к 2018 г. США столкнется с нехваткой от 140 000 до 190 000 профессиональных специалистов по обработке данных
# 6. 2012 г.  - Том Дэвенпорт и Д. Дж. Патил статья "Data Scientist: The Sexiest Job of the 21st Century"
# 7. 2014 г. Рост мобильных устройств
#
# #### Настоящее и будущее Data Science
#
# **Искуственный интеллект**  - сфера, в которой основное внимение уделяется созданию интеллектуальных машин, способных работать  и принимать решения как человек.
#
# **Машинное обучение** - инструмент для извлечения знаний из данных; модели могут обучаться на данных самостоятельно или поэтапно.
#
# **Глубокое изучение** - создание многослойных нейронных сетейв областях, где требуется более продвинутый или быстрый анализ, а традиционное машинное обучение не справляется. _Глубина_ - наличие более одного скрытого слоя нейронов в сети, которые проводят математические вычисления.
#
# **Большие данные**  - работа с огромными объемами часто неструктурированных данных. Специфика - инструмены и системы, способные выдерживать высокие нагрузки.
#
# #### 1.1.4 Чем занимается специалист по Data Science?
#
# Специалист по Data Science  решает бизнес-задачи с помощью следующих шагов:
#
# - задает правильные вопросы, чтобы понять проблему
# - собирает данные из нескольких источников - корпоративные данные, общедос­тупные данные
# - обрабатывает сырые данные и преобразует их в формат, подходящий для ана­лиза
# - загружает данные в аналитическую систему - алгоритм машинного обучения или статистическая модель
# - подготавливает результаты и идеи, которые можно изложить заинтересованным сторонам.
#
# Специалист решает проблемы:
#
# - обнаружение мошенничества и выявление аномалий, например изменений схе­мы снятия или расходования средств с кредитной карты клиента
# - целевой и персонализированный маркетинг - персональные рассылки по элек­тронной почте, системы рекомендаций на сайтах магазинов
# - метрические прогнозы - показатели эффективности, качества рекламных кам­паний и других мероприятий
# -  оценка принятия решений - обработка больших объемов данных и помощь в принятии решения, например о выдаче кредита на основе кредитных оценок
# - прогнозирующее моделирование- прогнозирование столкновения метеорита с землей на основе астрономических данных
#
# #### Профессии в области Data Science
#
# - специалист поданным (манипулирует огромными объемами данных)
# - дата-инженер  (работа с большими объемами данных, системами обработки и базами данных)
# - аналитик данных  (отвечает за сбор огромных объемов данных, поиск в данных отношений, закономерности и тенденций, составление отчестности и визуализацию для анализа данных)
# - статистик  (собирает, анализирует, обрабаотывает качественные и количественные данные, используя статистические теории и методы)
# - архитектор данных
# - администратор данных  (обеспечивает доступ к базе данных для всех пользователей)
# - бизнес-аналитик  (улучшение бизнес-процессов)
# -менеджер данных/аналитики
#
# ### 1.3 Основы компьютерного программирования
#
# #### 1.3.1 Что такое программирование?
#
# > Инструкции компьютеру должны быть конкретными и последовательными
#
# **Программирование** - это идеи, преобразованные в пошаговые инструкции
# **Алгоритм** - конечная последовательность четко определнных, реализуемых компьютером инструкций длятрешения кокой -либо  проблемы или для выполнения вычислений. Алгоритмы всегда однозначны и используются для вычислений, обработки данных, автоматизированных решений и других задач.
#
# **Комбинации алгоритмов**
#
# 1. Последовательные операторы (Пример: вычисление 2+2)
# 2. Условные операторы  (некоторая часть программы выполняется в зависимости от определенного условия. Если условие верное, компьютер выполняет одну часть программы, если неверное  - другую. )
# 3. Циклы и итерации (В некоторых программах определенный набор действий нужно выполнять снова и снова в зависимости от некоторого условия. Повторяющиеся действия – итерации. Итерация выполняется с использованием одного или нескольких операторов цикла, поэтому программы такого действия называются циклическими или повторяющимися)
# ### 1.3.3 Блок-схемы
#
# **Блок-схема** - это изображение алгоритмов в графической форме с использованием определенных значений. Для представления различных функций используются некоторые стандартные символы.
#
# ![image.png](attachment:image.png)
#
# #### 1.3.4. Что такое язык программирования?
#
# > Есть свои правила(синтаксис), значения (семантика)
#
# Компьютер использует _машинный язык_, языки программирования - _языки высокого уровня_.
#
# #### 1.3.5. Что такле исходный код?
#
# **Исходный код** - указания, которые мы даем компьютеру, написанные неформатированным текстом. Можно использовать тектовые редакторы: Notepad/Textedit. Исходный код может состоять из одной строки или тысячи сложных строк. Чтобы сохранить исходный код, нужно добавить расширение для Python - .py Hello_World.py
#
# #### 1.3.6 Как запустить исходный код?
#
# **Три способа перевода исходного кода  в машинный код:**
#
#  - компиляция
#  - интерпретация
#  - сочетание двух этих способов
#
#  Компилятор переводит/ компилирует исходный код с языка программирования высокого уровня на машинный язык. Пример программ: C, C++, Objective C
#
#  **Интерпретатор** - компьютерная программа, которая непосредственно выполняет инструкции, написанные на языке программирования, без предварительной компиляции в программу на машинном языке. Пример программ: PHP, Java Script
#
#  Пример программ с комбинацией обоих методов: Python, Java, C#
#
#  **Основные отличия компилятора от интерпретатора**
#
#  1. Компилятор генерирует автономную программу, написанную на машинном коде,  а система интерпретатора выполняет действия, описанные программой высокого уровня
#
#  2. После компиляции исходный код для запуска больше не требуется, у интерпретируемых программ исходный код требуется для запуска программы каждый раз
#
#  3. Обычно интерпретируемые программы работают медленнее, чем компилируемые
#
#  #### Что такое интегрированная среда разработки (IDE)?
#
#  Программы -  специальные инстументы, необходимые для написания, отладки и компиляции кода. Пример: Spyder IDE - бесплатная научная среда разработки на Python6 входит в состав дистрибутива Anaconda
#
#  #### 1.4 Резюме
#
#  Статистика - основа принятия всех решений, связанных с данными. Есть нескольо профессий в сфере Data Science, например, аналитик данных, дата-инженер. Во всех областях Data Science используется Python. Существует несколько комбинаций алгоритмов: последовательный, условный, циклы. Компьютер использует машинный язык, исходный код можно превратить в машинный через компиляцию, интерпретацию и сочетание этих способов. IDE - это программы, которые имеют специальные инструменты, необходимые для написания, отладки и компиляции кода.

# %% [markdown]
# ### Упражнения
#
# 1. В Data Science входят такие предметные области, как 1) глубокое обучение 2) машинное обучение 3) искуственный интеллект 4) большие данные. Общее между этими сферами - работа с данными, направленная на решение различных задач в науке и бизнесе. Различия: Искусственныйинтеллект(ИИ)-это сфера,в которой основное внимание уде­ляется созданию интеллектуальных машин, способных работать и принимать решения как человек. Машинное обучение- это инструмент для извлечения знаний из данны (самостоятельно или поэтапно). Глубокое обучение - это создание многослойных нейронных сетей в областях, где требуется более продвинутый или быстрый анализ, а традиционное машин­ное обучение не справляется. Большие данные- это работа с огромными объемами часто неструктуриро­ванных данных.
#
# 2. Алгоритм - конечная последовательность четко определнных, реализуемых компьютером инструкций длятрешения кокой -либо  проблемы или для выполнения вычислений. Алгоритмы всегда однозначны и используются для вычислений, обработки данных, автоматизированных решений и других задач. Алгоритмы можно изображать в графической форме с использованием определен­ных обозначений. Полученное изображение называется блок-схемой.
#
# 3. Признаки хорошей программы:
# - простое написание, не длинный и не короткий
# - легко читается
# - работающий
# - устойчивый
#
# 4. Компьютер понимает машинный язык
#
# 5. Отличие языка программирования от языков, на которых мы говорим:
# язык высокого уровня необходим для передачи команд компьютеру, так как напрямую писать на машинном языке сложно. Для языков программирования существуют интерпретаторы и компиляторы. На обычном языке мы разговариваем между собой.
#
# #### Правда или ложь
#
# 1. правда
# 2. ложь
# 3. ложь
# 4. правда
# 5. ложь
# 6. ложь
# 7. правда
# 8. ложь
# 9. правда
# 10. ложь

# %% [markdown]
# #### Практические задания
#
# 1. Алгоритм для расчета простых процентов для некоторой суммы
#
# Начало  функции
#
# Ввод данных: начальная сумма, процентная ставка, количество лет
#
# Вычисление простых процентов: Проценты = Сумма * (Процентная ставка / 100)*  Время
#
# Вывести результат : вывести проценты
#
# Конец функции
#
# 2. Алгоритм для вычисления площади прямоугольника
#
# Начало функции
#
# Ввод данных: длина стороны  и ширина стороны
#
# Вычисление площади прямоугольника: Площадь = Длина * Ширина
#
# Вывести результат: вывести Площадь прямоугольника
#
# Конец функции
#
#
# 3. Алгоритм вычисления периметра круга
#
# Начало
#
# Ввод данных: Радиус и Число Пи
#
# Вычисление периметра круга: 2 * Пи * Радиус
#
# Вывести результат: вывести периметр круга
#
# Конец функции
#
#
# 4. Алгоритм, который находит все простые числа меньше 100
#
# Начало
#
# Объявить переменную для хранения числа: Простые_числа = пустой список
#
# Число [0] = ложь
#
# Число [1] = ложь
#
# Применить функцию к каждому числу от 2 до 99 включительно
#
# Число_простое = Истина
#
# Для каждого делителя B от 2 до √A включительно проверить делители
#
# Если A делится на B без остатка тогда
#
#     число_простое = Ложь
#
#     Конец цикла
#
#     Конец Если
#
#     Конец Для
#
#     Если Число_простое тогда
#
#       Добавить А в Простые_числа
#
#     Конец Если
#
#     Конец Для
#
#     Вывести Простые_числа
#
#     Конец функции
#
#
#     5. Алгоритм превращения предложения, написанного в верхнем регистре в обычный для предложения регистр
#
#     Ввести строку XXXXX
#
#     преобразовать_в_нижний_регистр(предложение)
#
#     первая_буква = нижний_регистр[0].заглавная
#
#     остальные_буквы = нижний_регистр[1:]
#
#     Вывести предложение: первая_буква + остальные_буквы

# %% [markdown]
# 6. Блок-схема для приготовления льда из кипяченой воды с помощью холодильника.
#
# ![image-2.png](attachment:image-2.png)
#
# 7. Блок-схема для нахождения суммы всех четных чисел меньше ста.
#
# ![image.png](attachment:image.png)
#
# 8. Блок-схема для нахождения суммы всех нечетных чисел от 1 до 15 включительно.
#
#
# ![image-3.png](attachment:image-3.png)
#
# 9. Блок-схема вывода таблицы умножения на 3
#
# ![image-4.png](attachment:image-4.png)
#
# 10. Составить блок-схему для расчета сложных процентов с капитализацией.
#
# ![image-5.png](attachment:image-5.png)
