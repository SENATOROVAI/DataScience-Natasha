# %%
"""Глава 4."""

# %% [markdown]
# ### Объекты и операторы Puthon.
#
# ### 4.1 Переменные
#
# **Преременные** - указывают на объект, который им присвоен, значений сами по себе не имеют. Значения переменных могут меняться.
#
# Python автоматически определяет, какой тип значения присвоен переменной.
#
# `In[1]: print(type(x))`
#         `print(type(y))`
# <class 'int'>
# <class 'str'>
#
# #### 4.1.1. Оператор присваивания
#
# x = 38
# x - имя переменной
# = - оператор присваивания
# 38 - присвоенное значение
# > == - равно
#
# #### 4.1.2. Имена переменных
#
# **Правила синтаксиса**:
#  - Имена переменных могут содержать только буквы, цифры и нижние подчерки­вания
#
#  - Имя не должно начинаться с чис­ла. Имя Sfingers недопустимо.
#
#  - В имени нельзя использовать пробелы. Имя sales data недопустимо. Можно sales_data
#
#  -  Имена чувствительны к регистру.Sales иs ales-это две разные переменные.
#
#  - Имена переменных не могут совпадать с ключевыми словами. Это за­резервированные слова, которые для интерпретатора Python имеют особый смысл, например: and, break и try
#
#  > Чтобы получить список ключевых слов, можно запустить код, который выведет список ключевых слов:
# `In [2] : import keyword`
#         `print ( keyword . kwlist )`
#
# #### Структура программы
#
# **Части программы Python**: модули, выражения, операторы, объекты.
#
# - Программы состоят из модулей
#
# - Модули содержат выражения
#
# - Выражения содержат операторы
#
# - Операторы создают и обрабатывают объекты
#
# ### 4.3  Объекты
#
# > В Python выполняются операции над объектами(сложение, вычитание, умножение чисел как объектов, конконкатенация строк - _объединение нескольких в одну_). Все данные становятся объектами. Объекты могут быть **встроенными**, либо созданными с помощью классов.
#
# **Объект** - фрагмент памяти, содержащий значение, а также некоторые связанные с объектом операции. В Python все является объектами -  простые числа и выполняемые над ними операции. Python поддерживает ООП - объекто-ориентированные программирование.
#
# Объектная модель Python очень последовательная. Каждый объект имеет связанный с ним тип( например, целое число, строка) и его данные, что делает язык гибким.
#
# #### 4.3.1 Классификация объектов
#
# - встроенные
# - пользовательские
#
# - изменяемые
# - неизменяемые
#
# ![image.png](attachment:image.png)
#
# #### Преимущества встроенных типов
#
# Не нужно самостоятельно делать реализацию объекта( определять тип). Типы данных уже определены.
#
# - встроенные типы данных упрощают написание программ;
# - встроенные типы - это компоненты расширений;
# - встроенные типы часто более эффективны, чем пользовательские структуры данных;
# - встроенные типы данных являются стандартной частью языка
#
# #### 4.3.3. Идентификаторы, значения и типы объектов
#
# > Любые данные в программе Python представлены либо объектами, либо отношениями между объектам
#
# Объект можно представить как сочетание трех вещей:
# - идентификатор;
# - тип данных;
# - значение.
# > У каждого объекта есть идентификатор, тип и значение.
#
# **Идентификатор объекта**  - адрес объета в памяти, после его создания он никогда не меняется. Представлен числом. Его можно посмотреть с помощью функции id()
# `In[3]: a = 5`
#         `id(a)`
# Out[3]: 140703750332944
#
# **Тип объекта** определяет операции, которые объект поддерживает, а также возмож­ные значения для объектов этого типа. Функция type( ) возвращает тип объекта. Как и идентификатор, тип объекта также нельзя изменять.
#
# `In [ 6 ] : type ( a )` # а присвоено значение 5 , которое является целым, поэтому тип объекта - int.
# Out[б]: int
#
# #### 4.3.4. Изменяемые и неизменяемые объекты
#
# Изменяемость объекта определяетя его типом: числа, строки, кортежи(элементы упорядочены) неизменяемы, словари и списки изменяемы.
#
# **Контейнеры** - объекты, которые содержат ссылки на другие объекты. Пример: кортежи, списки, словари. Значение контейнера - ссылки на объекты (именно значения объектов, а не их адреса). Значение контейнера изменится при изменении значения объекта, но сам набор объектов неизменяем.
#
# #### 4.4 Стандартная иерархия типов
#
# **type()** - рассмотреть все типы в Jupyter Notebook
#
# #### 4.4.1. Встроенные костанты
#
# **None** - одно-единственное значение,один объект с таким значением. Доступ к таому объекту осуществляется через встроенное имя None. Используется для обозначения отсутствия значения, например, возвращается из функций, которые ничего явно не возвращают. В логическом смысле эквивалентен False.
#
# **Notimplemented** - одно-единственное значение,один объект с таким значением.    Доступ к этому объекту осуществляется через встроенное имя Notimplemented. Числовые методы и методы сравнения должны возвращать этот объект, если они не реализуют операцию для предоставленных операндов. В ло­гическом смысле эквивалентен True.
#
# **Ellipsis**  - - одно-единственное значение,один объект с таким значением. Доступ к этому объекту осуществляется через литерал . . .  или встро­ енное имя Ellipsis. В логическом смысле эквивалентен True.
#
# #### 4.4.2. Числовые типы
#
# Они создаются числовыми литералами и возвращаются арифметическими операто­рами и встроенными арифметическими функциями в качестве результата. Число­ вые объекты неизменяемы. Числа в Python, разумеется, связаны с числами в реальной математике, но с учетом огра­ ничений компьютерного числового представления.
#
# 1. **Целые числа(int)** - Это целые числа в неограниченном диапазоне, зависящем только от доступной (виртуальной) памяти. Для операций сдвига и маски используется двоичное представление, а отрицательные числа представлены в дополнительном коде, что создает иллюзию бесконечной строки знаковых битов, простирающейся влево.
#
# 2. **Логические значения (bool)** - Единственными логическими объектами являются True и False, представляющие логические значения. Логический тип является подтипом целочисленного, т. к. логические значения ведут себя как значения О и 1 почти во всех случаях, за ис­ключением того, что при преобразовании в строку возвращаются строки "True" и "False" соответственно.
#
# **Вещественные числа(float)** - Это числа с плавающей точкой двойной точности машинного уровня. Здесь диа­пазон значений и обработка переполнений задаются на уровне базовой машинной архитектуры (и реализации С или Java). Python не поддерживает числа с плавающей точкой одинарной точности, т. к. экономия на ресурсах процессора и памяти, которая обычно является причиной их использования, перекрывается накладными расходами на использование объектов в Python, поэтому нет при­чин усложнять язык двумя видами чисел с плавающей точкой.
#
# **Комплексные числа** - Комплексные числа представляются как пара чисел с плавающей точкой двой­ ной точности машинного уровня. Ограничения те же, что и у чисел с плавающей запятой. Действительную и мнимую части комплексного числа z можно полу­ чить с помощью атрибутов **z.real** и **z.imag**.
#
# #### 4.4.3. Последовательности
#
# **Последовательности** - конечные упорядоченные множества с индексацией неотрицательными числами. Встроенная функция len() возвращает количество элементов последовательности. Когда длина последовательности равна п, ее индексы лежат в диапазоне О, 1, ... , п - 1 . Чтобы выбрать i-й элемент последовательности а, нужно напи­ сать a[i].
#
# Последовательности также поддерживают операции срезов. Срез а[i:j) выбирает все элементы с таким индексом k, что выполняется неравенство i <= k < j. При использовании в выражении срез представляет собой последовательность того же типа. Это означает, что сам по себе срез тоже проиндексирован с О.
#
# Некоторые последовательности также поддерживают «расширенные срезы» с третьим параметром - _шагом_. Срез a [ i : j : k] выбирает все элементы а с индек­сом х, где выполняются условия: х = i + n * k, n >= О и i <= х < j
#
# #### Неизменяемые последовательности
#
# Неизменяемые последовательности не могут быть изменены после создания. Если объект содержит ссылки на другие объекты, то эти другие объекты могут изме­няться, но коллекция объектов, на которые ссылается эта неизменяемая последо­вальность, измениться не может.
#
# - **Строки(str)** - последовательность значений, кодируемых таблицей Unicode. В Python нет типа char, а символы представляются как строки длиной 1. Строки в Python заключаются в одинарные или двойные кавычки. Строки 'привет' и "привет" идентичны.
# Любые символы в диапазоне кодов от U + 0000 до U+10FFFF могут быть представле­ны в виде строки.
#
# `In[7]: bytes(b'nilabh')`
# Out[7]: b'nilabh'
#
# `In[8]: 'nilabh'` # строка, символ 'n' находится на 0-м индексе, а 'h'  на 5-м
#         'nilabh'[3] # срез строки по индексу 3 дает "a"
# Out[8]: 'a'
#
# `In[9]: ord ('a')`
# Out[9]: 97
#
# `In[10]: ord('nilabh'[3])`  # это то же самое, что и ord ('a')
# Out[10]: 97
#
# `In[11]: chr('97')` # функция chr() переводит целое число в символ
# Out[11]: 'a'
#
# `In[12]: print(chr(96))
#          print(chr(100))
#          print(chr(99))
#          print(chr(1045))
#          print(chr(96))
#          print(chr(100009))
#
# d
# c
# E
#
#
# - **Кортежи(turple)** - элементами кортежа могут быть любые объекты Pyhon. Кортеж из двух или более элементов формируется из списка выражений, разделенных запятыми. Кортеж из одного элемента можно создать путем добавления запятой к выражению  (выражение само по себе не является кортежем, а для группировки выражений в кортеж необходимо использовать круглые скобки). Пустой кортеж можно задать пустой парой  круглых скобок. Пример: ('xyz', 5, 'p')
#
# - **байтовые строки(bytes)** - Объект типа _bytes_  - неизменяемый массив. Его элементы представляют собой 8-битные числа x, такие что 0<= x <256. Для создания байтовых строк можно использовать байтовые литералы (например, b'abc') или встроенные конструктор bytes(). Кроме того, байтовые строки можно декодировать в строки с помощью метода decode().
#
# #### 4.4.3.2. Изменяемые последовательности
#
# При выполнении операций присваивания и удаления можно использовать индексы и срезы.
#
# Два внутренних типа изменяемые последовательностей:
#
# - **Списки (list)**
# Элементами списка могут быть произвольные объекты Python.  списки форматируются путем передачи списка выражений, разделенных запятыми, заключенного  в квадратные скобки (для формирования списка длины 0 или 1 особых обозначений не требуется)  Пример: ['xyz', 5, 'p']
# -**Байтовые массивы** (bytearray)
# Объект bytearray - это изменяемый массив. Такие массивы создаются встроенным конструктором bytearray(). Кроме того, что байтовые массивы являются изменяемыми (нехешируемыми), у них тот же интерфейс и функциональность, что и у неизменяемых байтовых объектов.
#
# #### 4.4.4. Множества
#
# Множества -  неупорядоченные конечные наборы уникальных неизменяемых объетов. Множества не индексируются, но можно перебирать их элементы в цикле, а встроенная функция len() возвращает количество элементов в наборе. Используются для быстрой проверки вхождения элемента, удаления дубликатов из последовательности, вычисления математических операций над множествами, таких как пересечение, объединение, разность и симметричная разность.
# Для элементов множества применяются те же правила неизменяемости, что и для ключей словаря. Числовые типы сравниваются по обыч­ным правилам числового сравнения, т. е. если два числа считаются равными (на­ пример, 1 и 1.0), то лишь одно из них может содержаться во множестве.
#  **Типы множеств**:
#  - Множества (set)  - изменяемые множества. Они создаются встроенным конструктором set()  и впоследствии могут быть изменены некоторыми методами, такими как add( ) .
# Пример множества: {"apple", "banana", "cherry"}
#
# - **Замороженные множества(frozenset)** -
#  неизменяемые множества. Они создаются встроенным конструктором frozenset(). Поскольку этот тип является неизменяемым и хешируемым, его можно включать в другие множества или использовать в качестве ключа сло­варя.
#
#  > Множества неупорядочены, поэтому их элементы возвращаются в случайном порядке. В Python множества заключаются в фигурные скобки. Обращаться к элементам мно­жества по индексам нельзя, поскольку множества неупорядочены, и у их элементов нет индекса.
#
#  #### 4.4.5. Сопоставления
#
#  Сопоставления представляют собой конечные наборы объектов, индексированных с произвольными индексами. Обращение вида a[k] позволяет выбрать из сопоставления a элемент  с индексом k. Этот синтакисис можно использовать в выражениях, в операторах присваивания  и в операторах del. Встроенная функция len() возвращает количество элементов в сопоставлении.
#
#  Два типа сопоставления:
#
#  - Словарь (dict).  Словарь представляет собой конечный набор объектов с почти произвольными индексами (ключами). В качестве ключей можно использовать все типы, кроме типов вроде списков или других словарей, которые являются изменяемыми и сравниваются по значению, а не по идентификатору объекта. Все дело в том, что для эффективной реализации словарей требуется, чтобы хеш-значения ключей не менялись. Числовые типы, используемые в качестве ключей, подчиняются обычным правилам числового сравнения: если два числа являются равными (на­ пример, 1 и 1 .0), то они оба могут использоваться для индексации одного и того же элемента словаря.
# Словари изменяемы. Создать словарь можно с помощью фигурных скобок { } .
# Примерсловаря: {"марка": "Форд", "модель": "Мустанг", "год": 1964}.
#
# #### 4.4.6. Вызываемые типы
#
# Это типы объектов, к которым может применяться операция вызова функции:
#
# - Встроенные функции
#
# Функция - это блок кода, который запускается только при ее вызове. В функ­цию можно передавать параметры. В конце выполнения функция может вернуть какие-то данные. Примеры встроенных функций: len ( ) и math.sin( ) (math - это
# стандартный встроенный модуль).
# Чтобы вызвать функцию, нужно написать имя функции, а за ним круглые скоб­ки. Например, len( ) - это функция, которая возвращает длину строки.
#
# - Пользовательские функции
#
# Пользовательская функция создается с помощью определения функции. Функция вызывается со списком аргумен­тов, в котором должно быть то же количество элементов, что и в списке фор­ мальных параметров функции в определении.
#
# - Методы
# Метод экземпляра объединяет класс, экземпляр класса и любой вызываемый
# объект (обычно пользовательскую функцию).
#
# - Встроенные методы
#
# То же самое, что и встроенные функции. Метод в Python  похож на функцию, за исключением того, что он относится к объекту.  Вызывая метод объекта, мы, вероятно, вносим в этот объект изменения. Таким образом, метод принадлежит классу. Примером является метод добавления элемента в список append( ).
#
# > Методы, в отличие от функций, вызываются у конкретного объекта
# > Функции вызываются сами по себе, т. е. они не привязаны к объектам
# > Поскольку метод вызывается у объекта, он может обращаться к его внутренним данным
# > Метод может изменять состояние  объекта, а функции обычно что-то принимают на вход, а в ответ возвращают значение или выводят что-то на экран.
#
# - Классы
# Классы
#
# Классы относятся к вызываемым объектам и объединяют в себе данные и функ­ циональность. Создание нового класса позволяет создать новый тип объектов, а в дальнейшем и новые экземпляры этого типа. Каждый экземпляр класса хранит атрибуты, определяющие его состояние. Экземпляр класса также может иметь
# методы (определяемые этим классом), изменяющие его состояние.
#
# - Модули
#
# Библиотека кода, файл с набором функций, которые нужно добавить в приложение. Чтобы создать модуль, нужно сохранить нужный код в  файле с расширением py. После этого вновь созданный модуль можно импортировать с помощью оператора
# import. Модули являются базовым элементом кода Python и создаются с помощью опера­ тора import или при вызове таких функций, как importlib.import_module() или import().
#
# ### Операции с объектами в Python
#
# - Мы не запрашиваем вывод результатов в явном виде. Результат печатается сам по себе при запуске кода.
# - Текст,написанный после символа #,пропускается и не считается частью кода. Поэтому в коде рекомендуется писать комментарии после символа #, чтобы сде­лать программу более читаемой.
#
# #### 4.6. Операторы
#
# **Выражения** - то, из чего состоит код. Пример: 2 + 3. В выражении можно выделить операторы и операнды.  **Операторы** - какие-то действия, могут быть представлены символами, такими как + ,или спациальными ключевыми словами. Опеарторами для реботы нужны данные, которые называются **операндами**.  2 и 3 - операнды.
#
# ####  4.6.1 . Арифметические операторы
#
# - '+' складывает два объекта :
#
# 4 + 3 дает 7
# 'a' + 'b' дает 'ab'
#
# - '-' выполняет вычитание одного числа из другого. Если первый операнд отсутствует, предполагается, что он равен нулю.
#
# -2.8 дает отрицательное число
# 70 - 34 дает 36
#
# - '*' возвращает произведение двух чисел или повторяет строку заданное число раз
#
# 2 * 3 дает 6
# 'ля' * 3 дает 'ляляля'
#
# - '**' степень
#
# x**y возвращает x в степени y
# 2**3 возвращает 8
#
# - '/' деление
#
# x/y делит число x на y
# 13/3 дадет 4,3333333
#
# - // целочисленное деление
#
# x//y делит x на y и округляет ответ до ближайшего целого числа, при этом, если одно из чисел является дробным, ответ тоже будет с плавающей точкой
#
# 13//3 дает 4
# -13//3 дает -5
# 9//1,81 дает 4.0
#
# - '%' остаток от деления
#
# 13%3 дает 1
# -25.5 % 2.25 дает 1.5
#
# #### 4.6.2. Операторы присваивания
#
# Эти операторы используются для присвоения значений.
# - Опеартор **=** означает писваивание, а не равенство( == ).
# - Оператор **+=** сначала добавляет к значению, содержащемуся в переменной a, значение переменной b, затем он присваивает переменной a результат этого сложения.
#
# При выполнении оператора %= первый операнд а делится на второй операнд ь, затем остаток от этого деления присваивается переменной а
#
# ![image-2.png](attachment:image-2.png)
#
# ####  4.6.3. Операторы сравнения
#
# - == равно, проверяет равенство объектов, например:
# x = 2, y = 2, x == y возвращает True
# x = 'str', y = 'stR', x == y возвращает False
# x = 'str', y = 'str', x == y возвращает True
#
# - != не равно, проверяет неравенство объектов, например:
#
# x = 2, y = 3, x !=y возвращает True
#
# - < меньше
# x < y проверяет, действительно ли x меньше y. возвращает True или False.
#
# 6< 4 дает False, 4 < 6 дает True.
#
# - '>' больше
#
# x > y проверяет, действительно ли x больше y
# 6 > 4 возвращает True. Если оба операнда являются числами, они сначала приводятся к общему типу, в противном случае всегда возникает False.
#
# - <=  меньше или равно
#
# х <= у проверяет, действительно ли х меньше или равно у
# х = 3; у = 6; х <= у возвращает True
#
# - '>= ' больше или равно
#
# х >= у проверяет, действительно ли х больше или равно у
# х = 4; у= 3; х >= 3 возвращает True
#
# #### 4.6.4. Логические операторы
#
# - **not**   логическое не
#
# Если х равен True, возвращает False.
# Если х равен False, возвращает True
#
# - **and** логическое и
#
# х and у возвращают значение False, если х равно False, в противном случае
# возвращается значение у.
# Пусть х = False; у = True. Тогда х and у возвращают False, поскольку х имеет значение False. В этом случае Python не будет вычислять значение у, по­скольку знает, что левая часть выражения and имеет значение False, и поэтому все выражение будет равно False независимо от других значений. Это называется сокращенной оценкой логического выражения
#
# - or логическое или
#
# Если х равен True, возвращает True, иначе возвращает оценку у.
# Пусть х = True; у = False. Тогда х or у возвращает True. Здесь также может выполняться сокращенная оценка
#
# #### 4.6.5. Операторы идентификации и вхождения
#
# Проверяют идентичность двух объектов.
# - is Если x - это тот же объект, что и y, выражение возвращает True, иначе False
#
# - is not  Если х не является тем же объектом, что и у, выражение возвращает True, иначе  False
#
# - Операторы вхождения проверяют, является ли данный объект элементом данной коллекци. Под коллекцией понимается последовательность или стуктура данных, например, строка, список, кортеж
#
# - in  Если х является элементом коллекции у, то возвращается тrue, в противном случае возвращается False
# - not in
# Если х не является элементом коллекции у, возвращается True, в противном случае возвращается False
#
# `In [13]: 4 is 2 * 2`
# Out [13]: True
#
# `In [14]: 'i' in 'string'`
# Out [14]: True
#
# `In [15]: x = [1, 2, 3, 'three', 4]`
# `print(2 in x)`
# `print(5 in x)`
# `print("three" in x)`
#
# True
# False
# True
#
# #### Отступы
# Определяют, к какому блоку кода принадлежит выражение
#
# Блок кода (тело функции, цикла и т. д.) начинается с отступа и заканчивается, когда появляется строка без такого отступа. Величина отступа остается на усмотрение программиста, но она должна быть одинаковой во всем блоке. Обычно 4 пробела - это предпочтительнее табуляции, например:
#
# `In [16]: if True:`
#          `print('Hello')`
# Hello
#
# `In[17]: if True`
#    `print ('Hello')`
#
# Будет ошибка IdentationError.
#
# ### 4.8. Комментарии в Python
#
# Комментарии делают код более чистабельным, позволяют понять, что делается в программе. Начинается с #, интерпретатор комментарии игнорирует.
#
# ### 4.9 Порядок выполнения
#
# **Приоритет операторов**
#
# Операторы, расположенные в одной строке, имеют одинаковый приоритет. Если синтакис не указан явно, операторы являются бинарными. Операторы одного приоритета выполняются слева направо( исключение: возведение в степень, которое выполняется справа налево)
#
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
#
# #### 4.9.1. Изменение порядка выполнения
#
# Использование круглых скобок  позволяет управлять порядком выполнения. Пример: (2 +3) * 4  - сложение, потом умножение
#
# #### 4.9.2. Ассоциативность
#
# Операторы с одинаковым приоритетом вычисляются слева направо.  2 + 3 + 4 эквавилентно (2 + 3) + 4. Исключение - оператор ** - ассоциативность справа налево
#
# ### 4.9.3 Площадь прямоугольника
#
# `In[18]:` # sвчисление площади прямоугольника
#         Lenth = 5
#         Width = 8
#         Area = Lenth * Width
#         print('Area of the Rectangle is', Area)
#         print('Perimeter of the rectangle is', 2 * (Lenth + Width))
# Area of the rectangle is 40
# Perimeter of the rectangle is 26
#
# ### 4.10 Динамическая типизация
#
# В Python значение, на которое указывает переменная, имеет определенный тип данных, но сама переменная не имеет строгого типа. Можно  повторно исполь­зовать одну и ту же переменную, передавая ей ссьmку на объект уже другого типа.
#
# `In[19]: six = 6`
#          `six`
# Out[19]: 6
#
# `In[20]: six = 'six'`
#          `six`
# Out[20]: 'six'
#
# ### 4.11 Строгая типизация
#
# Для некоторых операций требуются аргументы определенного типа.
# `In[21]: 'day' + 1`
#
# TypeError Traceback (most recent call last)
# <ipython-input-31-91cbfбala000> in <module>
# ----> 1 'day'+l
# TypeError: can only concatenate str (not "int") to str
#
# > Можно изменить тип объекта встроенной функцией
#
# `In[22]: 'day' + str('1')`
# Out[22]: 'day 1'
#
# ### 4.12. Логическая и физическая строка
#
# **Физическая строка** - то. что мы видим на экране, когда пишем выражение.
# **Логическая строка** - то, что Python считает единым выполняемым выражением. Каждая физическая строка соответствует логической строке.
#
# `In[23]:` # здесь две физические строки  и две логические строки
#         `i = 5`
#         `print(i)`
# 5
#
# `In[24]: # здесь одна физическая строка, но две логические
#         i = 5; print(i)
# 5
#
# > Чтобы записать более одной логической строки на одной физической строке, нужно использовать точку с запятой (;), которая отмечает конец логи­ ческой строки/оператора.Это делает код более читабельным. Пример:
#
# `i = 5`
# `print(i)`
#
# `i = 5;`
# `print(i);`
#
# `i = 5; print(i)`
#
# `i = 5; print(i)`
#
# ### 4.13. Резюме
#
# Семантика Python - существуют переменные, операторы, объекты, провила написания перменных, особая структура программы Python. Есть также специальные структура и иерархия кода Python. Выражения, операторы и операнды - строительные блоки программы.

# %% [markdown]
# #### 4.14. Упражнения
#
# 1. Переменная в Python - это некоторое имя, связанное со значением. Переменные указывают на объект, который им присвоен, значений сами по себе не имеют. Значения могут меняться. Объект - фрагмент памяти, содержащий значение.
#
# 2. Правила именования переменных:
# - Имена переменных могут содержать только буквы, цифры и нижние подчеркивания.
# -Имена переменных не могут начинаться с цифр.
# - В имнени переменных нельзя делать пробелы.
# - Имена переменных чувствительны к регистру.
# -Имена переменных не могут совпадать с ключевыми словами Python. Ключевые слова можно прочитать, запустив код
# import keyword
# print (keyword . kwlist).
# Пример: False, True, and, as, assert.
#
# 3. Преимущества встроенных типов данных:
#
# - нет необходимости самостоятельно писать реализацию кода
# - встроенные типы данных упрощают написание программ
# - встроенные типы - компоненты расширений
# - встроенные типы эффективнее, тем пользовательские структуры данных
# - встроенные типы являются стандартной частью языка
#
# 4. Неизменяемый объект - это объект, значение которого после создания остается неизменным. Числа, строки и кортежи неизменны.
#
# 5. Идентификатор объекта - это адрес объекта в памяти. Идентификатор объекта после его создания никогда не меняется. Представлен числом, его можно посмотреть с помощью функции id(). Тип объекта определяет операции, которые тот поддерживает, а также возможные значения для объектов этого типа. Тип объекта нельзя изменить, операция type() возвращает тип объекта.
#
# 6. Функции chr() переводит целое число, которое представляет код символа в Unicode, в символ, а ord() - символ в целое число.
#
# 7. Оператор - какие-то действия над операндами, которые могут быть представлены символами или специальными ключевыми словами. Виды операторов:
# 1. Арифметические (например,  '+', '-', '*')
# 2. Операторы присваивания(например, '=', '+=')
# 3. Операторы сравнения (например, '==', '!=', '>')
# 4. Логические операторы (not, and, or)
# 5. операторы идентификации( is, is not ) и  вхождения (in , not in)
#
# 8. Оператор '//'  -  выполняет целочисленное деление без остатка, а оператор '/' - простое деление с остатком
#
# 9. Логические операторы:
# 1. not: Если х равен True, возвращает False, если х равен False, возвращает True
# 2. and: если  х = False; у = True, тогда х and у возвращают False, поскольку х имеет значение False. В этом случае Python не будет вычислять значение у, по­ скольку знает, что левая часть выражения and имеет значение False, и поэтому все выражение будет равно False независимо от других значений ( сокращенная оценка логического выражения)
# or: если х равен тrue, возвращает True, иначе возвращает оценку у. Если  х = True; у = False. Тогда х or у возвращает True. ( сокращенная оценка логического выражения)
#
# 10. Отступы в языке программирования Python определяют, к какому блоку кода принадлежит выражение. Блок кода (тела функции, цикла) начинается с отступа и заканчивается, когда появляется строка без такого отступа.
#
# 11. Комментарии в Python пишутся с помощью знака '#'. Они нужны для того, чтобы сделать код более читабельным, дать разъяснения.
#
# 12. Для того, чтобы изменить порядок выполнения операторов в Python, нужно использовать круглые скобки.  ё
#
# 13. Физическая строка - это то, что мы видим на экране, когда пишем программу, а логическая - это то, что Python видит единым выполняемым выражением.
#
# #### 4.14.2  Правда или ложь
#
# 1. Правда
# 2. Ложь
# 3. Правда
# 4. Правда
# 5. Ложь
# 6. Ложь
# 7. Правда
# 8. Правда
# 9. Ложь
# 10. Правда

# %%
# Питер получает зарплату 1 2 ООО в месяц. Напишите код для вычисления его сбе­ режений к концу года, если он будет откладывать 20% своей зарплаты каждый месяц.
month_salary = 12000
full_time = 12
percentage = 20
month_savings = month_salary * percentage / int(100)
full_savings = month_savings * full_time
print(full_savings)
# Out:
# 28800.0

# %%
# Расстояние между Мумбаи и Дели составляет 1422 км. Если Сундар едет на ма­ шине со средней скоростью 72 км/ч, сколько времени ему потребуется, чтобы преодолеть это расстояние?

distance = 1422
speed = 72
time = distance / speed
print(time)
# Out:
# 19.75

# %%
# Температура тела человека находится в диапазоне от 97 до 99 по Фаренгейту.
?Цельсия


def fahr_to_celc(fahr):
    celc = (fahr - 32) * 5 / 9
    return celc


lower_bound_f = 97
upper_bound_f = 99

lower_bound_c = fahr_to_celc(lower_bound_f)
upper_bound_c = fahr_to_celc(upper_bound_f)
print(
    f"Температура тела человека находится в диапазоне  от {lower_bound_c:.1f} до {upper_bound_c:.1f} по Цельсию."
)
# Out:
# Температура тела человека находится в диапазоне  от 36.1 до 37.2 по Цельсию.

# %%
# Пусть дано шестизначное число. Напишите программу для вычисления суммы всех цифр этого числа.
num = int(input("Введите шестизначное число: "))
digits_sum = sum(int(i) for i in str(num))
print(digits_sum)
# Out:
# 21

# %%
# У нас есть данные о месячных продажах 5 книжных магазинов в Бруклине:
А=$6500,В=$8000, С=$ 12ООО,D=$4900 и Е=$5600. Предполагая, что в Бруклине всего 5 книжных магазинов, узнайте рыночную долю каждого магазина. Также проверьте, какой будет сумма рыночных долей всех магазинов. (Рыночная доля означает отношение одного участника ко всем остальным.)
selling_1 = 6500  
selling_2 = 8000  
selling_3 = 12000  
selling_4 = 4900  
selling_5 = 5600  
sum_selling = selling_1 + selling_2 + selling_3 + selling_4 + selling_5  
share_1 = selling_1 / sum_selling * int(100)   
share_2 = selling_2 / sum_selling  * int(100)   
share_3 = selling_3 / sum_selling * int(100)     
share_4 = selling_4 / sum_selling * int(100)    
share_5 = selling_5  / sum_selling * int(100)    
print(share_1,share_2,share_3, share_4, share_5)  
sum_share = share_1 + share_2 + share_3 +  share_4 + share_5  
print(sum_share)
# Out:
# 17.56756756756757 21.62162162162162 32.432432432432435 13.243243243243244 15.135135135135137
# 100.0

# %%
# Среднее значение трех чисел равно 45. Первое число больше среднего значения настолько же, насколько второе число меньше среднего значения. Найдите третье число.


def find_numbers(avg):
    total_sum = avg * 3
    for first in range(total_sum + 1):
        for second in range(total_sum + 1):
            for third in range(total_sum + 1):
                if (
                    first > avg
                    and second < avg
                    and first - avg == avg - second
                    and (first + second + third) // 3 == avg
                ):
                    return first, second, third
    else:
        return (None,) * 3


print(find_numbers(45))
# Out:
# (46, 44, 45)

# %%
# Джон покупает мобильный телефон за 1 800 в Калькутте и продает его в Мум­ баи с прибылью 25%. Если его накладные расходы составляют 5% от цены продажи, то какова цена продажи?

buy_price = 1800
income_in_percent = 25
income = buy_price * income_in_percent / 100
sell_price = buy_price * income / 100
spendings_in_percent = 5
spendings = sell_price * 5 / 100
final_sell_price = sell_price - spendings
print(f"final_price is {final_sell_price}")
# Out:
# final_price is 7695.0

# %%
# Найдите объем и площадь куба с диагональю 5 м.
import math

diagonal = 5
sqrt = math.sqrt(5)
vol = diagonal**3 / (3 * 3**0.5)
sqr = 2 * diagonal**2
print(f"volume is {vol}, square is {sqr} ")
# Out:
# volume is 24.056261216234407, square is 50

# %%
# Три металлических куба с ребрами длиной 3, 4 и 5 см соответственно пере­ плавляются в один куб. Найдите длину ребра нового куба.
import math

vol_1 = 3**3
vol_2 = 4**3
vol_3 = 5**3
sum_vol = vol_1 + vol_2 + vol_3
side = math.cbrt(sum_vol)
print(f"New side is {side}")
# Out:
# New side is 6.0

# %%
# Дано шестизначное число. Напишите программу для получения числа с обрат­ным порядком цифр.
num = int(input("Введите шестизначное число: "))
num_reversed = int("".join(reversed(str(num))))

print(num_reversed)
# Out:
# 654321
