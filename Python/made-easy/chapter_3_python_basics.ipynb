# %%
"""Глава 3."""
# Out:
# 'Глава 3.'

# %% [markdown]
# #### 3.1 .1 . Использование Spyder IDE
#
# 1. Открыть Anaconda Navigator
# 2. Нажать кнопку Launch под приложением Spyder
#
# **Основные компоненты Spyder**:
#
# - Редактор: нумерация строк, выделение синтаксиса, функции автозаполнения и т. д.
#
# - Консоль IPython: доступно любое количество консолей, графический интерфейс, можно запускать код по строкам, ячейкам или файлам, отображать графики в строке.
#
# - Обозреватель переменных: позволяет взаимодействовать с переменными и изменять их на лету, строить гистограмму или временной ряд, редактировать датафреймы или массивы Numpy - отображаются создаваемые объекты.
#
# #### 3.1 .2. Использование Jupyter Notebook
#
# 1. Открыть Anaconda Navigator
# 2. Нажать кнопку Launch под приложением Jupyter Notebook. Стартовое окно Jupyter Notebook откроется в браузере, который установлен по умолчанию
# 3. Чтобы создать документ Notebook - нажать кнопку New в правом верхнем углу  и выбрать пункт меню Python.  Откроется новая веб-страница с одной пустой ячейкой и без имени
# 4. Чтобы запустить строку кода, нужно ввести ее в ячейку, оставить тип ячейки Code и использовать из способов запуска:
#
# - пункт меню Cell
# - горячими клавишами:
# Shift + Enter  - запустить ячейку и перейти к следующей
#
# Ctrl + Enter - запустить выбранные ячейки
#
# Alt + Enter - запустить ячейку и вставить новую ниже
#
# #### «Hello World!»
#
#  ```In [1]: print(Hello World!)```
# Hello World!
#
# ### 3.3. Использование Python как калькулятора
#
# `In[2]: 2 + 2`
# Out[2]: 4
#
# `In[3]: 50 - 5 * 6`
# Out[3]: 20
#
# `In[4]: (50 - 5 * 6) / 4`
# Out[4]: 5.0
#
# `In[5]: 8 / 5`
# Out[5]: 1.6
#
# > int - тип целых чисел
# > float -  тип  чисел с дробной частью
# > // - делить нацело и получить целочисленный результат
# > % - вычисление остатка
#
# `In[6]: 17 / 3` # обычное деление с плавающей точкой
# Out[6]: 5.666666667
#
# `In[7]: 17 // 3` # целочисленное деление
# Out[7]: 5
#
# `In[8]: 17 % 3` # остаток от деления
# Out[8]: 2
#
# `In[9]: 5 * 3 + 2`
# Out[9]: 17
#
# `In[10]: 5 ** 2` # 5  в квадрате
# Out [10]: 25
#
# > Знак равенства = используется для присвоения значения переменной. После при­ своения результат не отображается.
#
# `In[11]: width = 20`
#
#          `height = 5 * 9`
#
#
# #### 3.3.2. Строки
#
# > Строки могут быть заключены в " " или ''
# > \ - экранирование
#
# `In[12]: 'python strings'`
# Out[12]: 'python strings'
#
# `In[13]: 'doesn\'t'`
# Out[13]: "doesn't"
#
# `In[14]: "doesn't"`
# Out[14]: "doesn't"
#
# > Функция print() - более читаемый вывод без кавычек и вывод экранированных и специальных символов
#
# `In[15]: print('"Isn\'t," they said.')`
# "isn't, they said.
#
# > r - перед первой кавычкой  - управляющие символы \n, \t  - интерпретируются как специальные
#
# `In[16]: print('C:\some\name')` # \n - переход на новую строку
# C:\some
# ame
#
# `In[17]: print(r'C:\some\name')`
# C:\some\name
#
# ####  3.3.2.1 .Конкатенация и повторение
#
# > Оператор +  - склеивание строк
#
# `In[18]: 'a' + 'b'`
# Out[18]: 'ab'
#
# > Оператор *  - умножение строк
#
# `In[19]: 't' * 5`
# Out[19]: 'ttttt'
#
# `In[20]:'no' * 3 + 'dip'`
# Out[20]: 'nononodip'
#
# > Два или более строковых литерала (заключенных в кавычки строки), расположен­ных рядом друг с другом, автоматически объединяются. Используется для разделения длинных строк.
#
# `In[21]: 'nil' 'abh'`
# Out[21]: 'nilabh'
#
# `In[22]: text = ('Put several strings within parenthess -'`
#                 `'- to have them joined together.')`
# Out[22]: 'Put several strings within parenthess --  to have them joined together.'
#
#
# ####  3.3.2.2. Индексирование
#
# **Индексировать строки** - обращаться  к элементам строки по индексу. Первый символ имеет индекс 0.
#
# **Индексирование Python**
#
# | p  | y  | t  | h  | o  | n  |
# | -- | -- | -- | -- | -- | -- |
# | 0  | 1  | 2  | 3  | 4  | 5  |
# | -6 | -5 | -4 | -3 | -2 | -1 |
#
# Первая строка - индексы букв в строке, вторая строка  - соответствующие отрицательные индексы
#
# `In[25]: word = 'Python'`
#          `word[o]`
# Out[25]: 'p'
#
# `In[26]: word = 'Python'`
#          `word[-4]`
# Out[26]: 't'
#  > Поскольку -О равняется О, то отрицательные индексы начина­ ются с - 1
#
# #### 3.3.2.3. Срезы
#
# Срез возвращает подстроку
#
# `In [27] : word[0:2]`  # с позиции О (включительно) до 2 (не включая его)
# Out [27]: 'Py'
#
# `In [28] : word[2:5]` # с позиции 2 (включительно) до 5 (не включая его)
# Out[28]: 'tho'
#
# > Hачальный индекс всегда включается, а конечный всегда исключается. Это гарантирует, что s [:i] + s [i:] всегда равно s.
#
# `In[29]: word[:2] + word[2:]`
# Out[29]: 'Python'
#
# > Опущенный первый индекс по умолчанию равен нулю, опущенный второй индекс по умолчанию равен длине строки.
#
# > Присвоить новое значение символу по определенному индексу нельзя.
#
# > встроенная функция len ( ) возвращает длину строки len(word)
#
# `In[30]: len(word)`
# Out[30]: 6
#
#
# ### 3.4. Синтаксис кода Python
#
# #### 3.4.1 Выражения
#
# **Выражения** -  строки, написанные в исходном коде, они могут состоять из операторов разного типа, например, оператор присваивания, условный оператор, оператор цикла. *n = 20* - выражение с оператором присваивания.
#
# > Выражения могут быть однострочными или многострочными. Многострочные вы­ражения можно переносить на другие строки с помощью круглых скобок ( ), фигурных скобок {}, квадратных скобок [], обратной косой черты (\).
#
#  - перенос выражения на новую строку с использованием \
# s=1+2+3+\
# 4+5+6+\
# 7+8+9
#
# - перенос выражения на новую строку с использованием ()
# n = (1 * 2 * 3 + 7
#  / 8 + 9 )
#
#  - перенос выражения на новую строку с использованием [] footballer = ['МESSI',
# ' NEYМAR ',
# ' SUAREZ ' ]
#
# - перенос выражения на новую строку с использованием { }
# х = {1 + 2 + 3 +
#      + 7}
#
# ##### 3.4.1.1.   Окончание выражений
#
#  > Можно завершить выражение с помощью точки с запятой (;), за счет этого разместить несколько выражений в одной строчке.
#
# flag = 2; ropes = 3; pole = 4
#
# #### 3.4.2.  Переменные и присваивание значений
#
# **Переменная** -  некоторое имя, связанное со значением. Переменная лишь ссылается на значение, но не тождественна ему. Когда переменной присваивается другое значение, старое присвоенное сразу становится недействительным. Оператор присваивания позволяет автоматически создавать новые переменные и присваивать им значения.
#
# ` In[31]: a = 45`
#         `print(a)`
# 45
#
# `In[32]: a = 3 + 2` # присваеваем новое значение
#          `print[a]`
# 5
#
# #### 3.4.3  Имена переменных и ключевые слова
#
# > Для переменных следует выбирать имена со смыслом, которые что-то говорят о хранимых данных. Имена переменных могут быть любой длины и содержать как буквы, так и числа. Писать имена можно в верхнем или нижнем регистре, но одно и то же имя с раз­ ными регистрами - это будут разные переменные, т. к. Python чувствителен к ре­гистру.
#
# **Правила именования переменных**
#  - Имя должно начинаться с буквы(не с цифры).
#  - В имени может присутствовать символ подчеркивания (_). Он используется для соединения слов в длинном имени переменной, т к. ппробелы использовать нельзя.
#  - Нельзя использовать в качестве имен переменных ключевые слова Python:
#  - and
#  - def
#  - ехес
#  - if
#  - not
#  - return
#  - assert
#  - del
#  - finally
#  - import
#  - or
#  - try
#  - break
#  - elif
#  - for
#  - in
#  - pass
#  - while
#  - class
#  - else
#  - from
#  - is
#  - print
#  - yield
#  - continue
#  - except
#  - global
#  - lambda
#  - raise
#
#  ####  3.4.4. Выполнение выражений
#
#  **Выражение** - совокупность значений, переменных и операторов. (Не обязательно все сразу). Вычислить выражение - это не то же самое, что вывести его значение на экран.
#
#  >   множественное присваивание: переменные а и b  одновременно получают значения о и 1:  a, b = 0, 1
#  > перед таким присваиванием всегда сначала вычисляется правая часть: a, b = b, a + b
#  > Цикл while выполняется до тех пор, пока условие остается истинным. В Python ис­тинным является любое ненулевое целочисленное значение, ноль считается ложным. Условие также может быть строкой или списком и вообще любой по­следовательностью. При этом все, что имеет ненулевую длину, считается истин­ным, а пустые последовательности - ложными. стандартные операторы сравнения: < (меньше), > (больше), == (равно), <= (меньше или равно), >= (больше или равно) и ! = (не равно)
#  > Тело цикла записано с отступом. **Отступы** - это способ группировки выраже­ний в Python. В интерактивном режиме интерпретатора для задания отступа нужно использовать табуляцию или пробелы. На практике код бывает гораздо более сложным, и у всех специализированных текстовых редакторов есть функ­ция автоматического отступа. Когда составное выражение вводится в интерак­тивном режиме, за ним должна следовать пустая строка, указывающая на завер­шение (поскольку синтаксический анализатор не может угадать, когда блок кода закончился). У всех строк в блоке должен быть одина­ковый отступ.
#  > Функция **print()** выводит значение переданного аргумента на экран. Строки выводятся без кавычек, а между аргументами вставляется пробел, что позволяет красиво форматировать результаты
#   `In [33] : i = 256 * 256`
#    `print('The value of i is', i)`
#    The value of i is 65536
#
#    #### 3.5.1.  Функции print()
#
#  - **Аргументы(args)** - все то, что мы передаем в функцию. Например, аргументы - строка, класс или переменные, которые мы передаем в функцию print()
#  ***args** - передать функции любое количество переменных (можно *objects)
#  - **именованные аргументы(rwargs)**  - аргументы, для которых ппри передаче в функцию указывается не только значение, но и имя.
#
#  sep='' sep - именованный аргумент, у него есть имя, справа от символа = указано присвоенное ему значение.
#
#  **Значение по умолчанию** - значение, указанное в определении функции. Если не занзачить аргументу другое значение, будет передано значение по умолчанию, синтаксических ошибок не возникнет.
#
#  **Параметры функции print()**
#
#  - *objects  - любое количество объектов. Перед выводом все объекты собираются в строку.
#
#  - sep='' (необязательный) - задает разделитель объекто, если их несколько. Значение по умолчанию - символ пробела, указанный как ' '
#  - end=' ' (необязательный) - определяет, что вывести в конце строки. Значение по умолчанию - символ переноса строки '\n'
#  - filr=sys.stdout (необязательный) - объект с методом write(string). Если этот парамет не указан, будет использоваться sys.stdout по умолчанию, что означает вывод результатов на экран.
#  - flush=False (необязательный) - логическое заявление, указывающее, будет ли вывод очищен (True) или буферезирован (False). По умолчанию - False
#
#  #### 3.5.2. Форматированный вывод
#
#  `In[34]:  a = 5`
#            `b = 6`
#            `ab = 5 * 6`
#            `print("when {} is multiplied by {}, the result is {}".format(a, b, ab))`
# When 5 is multiplied by 6, the result is 30.
#
# #### 3.5.3. Простейшая геометрия  и print()
#
# ![image.png](attachment:image.png)
#
#
# ###  3.6. **Основные виды ошибок**
# - Синтаксическая ошибка - проблемы с языковыми конструкциями
# - Ошибка времени выполнения - проблемы с выполнением кода.
# - Семантическая ошибка - неожиданный результат.
#
# #### 3.6.1. Синтаксические ошибки
#
# Вызваны опечатками или возникла проблема со структурой программы. Не соблюдается синтаксис Python.
# `In[35]: # отсутствует закрывающая кавычка
#         print("Hello World!)
# File "<ipython-input-49-9d0e3bd45f27>", line 3
#         print ("Hello World! )
#
# SyntaxError: EOL while scanning string literal
#
# Указано место ошибки
#
# #### 3.6.2.  Ошибки времени выполнения
#
# Возникают во время работы программы. Поскольку Python является интерпретируемым языком, такие ошибки возникают лишь в тот момент, когда выполнение программы доходит до ошибочной строки.
#
# **Причины ошибок времени выполнения**
#
# - неверно введенное имя переменной или функции
# - использование переменной до ее определения
# - имя должно быть заключено в кавычки
# - деление на ноль
#
# Ошибка времени выполнения возникает, когда Python понимает саму команду, но при ее выполнении сталкивается с проблемами. Поэтому эта ошибка и называется «времени выполнения», поскольку возникает только после запуска программы.
#
# `In[36]: 5/0`
#
# ZeroDivisionError Traceback (most recent call last) <ipython-input-51-0106664d39e8> in <module>
# ----> 1 5/0
# ZeroDivisionError: division Ьу zero
#
# ####  3.6.3. Семантические ошибки
#
# **Семантические или логические ошибки**- это проблемы с самим построением вашей программы. Обычно такие проблемы не вызывают сообщений об ошибках, но поведение программы оказывается неверным.
#
# Эти ошибки часто бывают вызваны случайным использованием неверных пере­ менных либо просто неправильными вычислениями.
#
# `In[37]: # вывести "Hello Nilabh"`
#         `name = "Nilabh"`
#         `print("Hello name")`
# Hello name
#
# #### 3.6.4. Альтернативные методы устранения ошибок
#
# - Поиск в интернете stackoverflow.com
# - Избегать таких случаев, писать по несколько строк кода, а потом выполнять программу.
# - Промежуточные версии. Сохранять промежуточный промежуточный прогресс в разра­ботке программы каждый раз, когда начинаем  писать новую часть. Если достигли определенного этапа, сделайть резервную копию. Для этого достаточ­ но выбрать пункт меню **Save as** и назвать свой файл **filename2.py**, затем **filename3.py** и т. д. Если вы работаете с filename7.py и столкнулись с нерешае­мой проблемой, можно просто вернуться к filename6.py. По окончании работы можно просто убрать все старые файлы в архив и переименовать окончательный файл по своему усмотрению.
# - Комментарии. Закомментировать проблемный участок кода, чтобы посмотреть, сохранится ли проблема. Можно использовать воз­можности среды IDE, чтобы поместить символ комментария перед всеми стро­ками выделенного фрагмента кода. Изолировать разные участки кода, чтобы сузить область поиска проблемы.
# - Все сначала.  Начать писать код заново с нового пустого файла, затем скопировать и всавить небольшие фрагменты кода из старого файла по одному. Каждый раз, добавляя новый раздел, запускать программу и проверять, не появилась ли проблема.
#
# ### Резюме
#
# Python можно использовать как калькулятор, проводить манипуляции со строками, работать с выражениями, операторами и переменными.Существует ряд принципов написания кода на Python, например, множественное присваивание, отступы, цикл, вывод результата. Существует функция print() и аргументы и именные аргументы. Виды ошибок  в Python: Синтаксическая ошибка, Ошибка времени выполнения, Семантическая ошибка.

# %% [markdown]
# #### Упражнения
#
# 1. Преимущества Spyder IDE по сравнению с простым текстовым редактором:
#
# - Редактор Spyder имеет более широкий функционал, включающий нумерацию строк, выделение синтаксиса, функции автозаполнения, в нем можно пользоваться инструментами анализа кода, автоматическим завершением кода, горизонтальным/ вертикальным разделением, переходом к определению объекта.
#
# - Консоль предоставляет возможности любого количества консолей IPython в сочетании с гибкостью графического интерфейса. Можно запус­кать код по строкам, ячейкам или файлам, а также отображать графики прямо в строке.
#
# - Обозреватель переменных позволяет взаимодействовать с переменными  и изменять их на лету, строить гистограмму или временной ряд, редактировать датафреймы  или массивы Numpy, сортировать коллекции
#
# 2. Оператор сложения в Python: +
# вычитания: -
# умножения: *
# деления: / - простое, // - целочисленное
#
# 3. Оператор * - умножение, оператор ** - возведение в степень.
#
# 4. Выражения в Python -  совокупность значений, переменных и операторов. При введении выражения в командной строке, интерпретатор вычисляет его и выводит результат.
#
# 5. Переменная - некоторое имя, связанное со значением. Чтобы присвоить переменной значение, нужно ввести оператор присвоения "=".
#
# 6. Переменной нельзя дать имя import, так как это ключевое слово Python, которые согласно правилу именования переменных использовать нельзя.
#
# 7. Имена math, Math и MATH не эквивалентны, так как у них отличается регистр, следовательно, они определяются как разные объекты.
#
# 8. Выражения в Python можно группировать по способу отступа через табуляцию или пробелы. Если выражение составное и выводится в интерактивном режиме, за ним должна следовать пустая строка, указывающая на завершение. У всех строк в блоке должен быть одинаковый отступ.
#
# 9. Синтаксическая ошибка означает, что возникла проблема со структурой программы, не соблюдается синтаксис Python. семантическая ошибка - проблема с построением программы, в результате поведение программы оказывается неверным. Такая ощибка может быть вызвана использованием неверных переменных или неправильными высислениями.
#
# 10. По умолчанию аргументы sep и end в синтаксисе функции print() имеют значение, указанное в определении функции.
#
#
#
#
#
# #### 3.8.2. Правда или ложь
#
# 1. Ложь
# 2. Правда
# 3. Ложь
# 4. Ложь
# 5. Ложь
# 6. Ложь
# 7. Ложь
# 8. Правда
# 9. Ложь
# 10. Правда

# %%
name = "Natasha"
surname = "Akisheva"
print(name, surname, sep=" ")
# Out:
# Natasha Akisheva

# %%
length = 23
height = 8
square = length * height
print(square)
# Out:
# 184

# %%
print(23**2)
print(pow(27, 3))
# Out:
# 529
# 19683

# %%
a_ = 2
b_ = 4
left_side = (a_ + b_) ** 2
right_side = a_**2 + b_**2 + 2 * a_ * b_
print(left_side)
print(right_side)
if left_side == right_side:
    print("equal")
else:
    print("not_equal")
# Out:
# 36
# 36
# equal

# %%
print(len("Natalia"))
# Out:
# 7

# %%
print("-----------")
print("|         |")
print("|         |")
print("-----------")
# Out:
# -----------
# |         |
# |         |
# -----------

# %%
print("-----")
print("|   |")
print("|   |")
print("-----")
print("|")
print("|")
# Out:
# -----
# |   |
# |   |
# -----
# |
# |

# %%
Name = "Natasha"
Age = 23
print(f"Меня зовут {Name}, а мой возраст - {Age}.")
# Out:
# Меня зовут Natasha, а мой возраст - 23.

# %%
words = ["cat", "window", "defenestrate"]
for w_ in words:
    print(w_, len(w_))
# Out:
# cat 3
# window 6
# defenestrate 12

# %%
а_, Ь_ = 0, 1
while а_ < 15:
    print(а_, end=",")
    а_, Ь_ = Ь_, а_ + Ь_
# Out:
# 0,1,1,2,3,5,8,13,

# %% [markdown]
# #### Изучите самостоятельно
#
# | н  | а  | т  | а  | ш  | а |
# | -- | -- | -- | -- | -- | --|
# | 0  | 1  | 2  | 3  | 4  | 5 |
# | -6 | -5 | -4 | -3 | -2 | -1|
