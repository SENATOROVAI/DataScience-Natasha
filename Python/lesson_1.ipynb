# %%
"""Модуль посвящен первому уроку.

В данном модуле рассматривали работу с 
гит.
"""
# Out:
# 'Модуль посвящен первому уроку. В данном модуле рассматривали работу с \nгит.'

# %% [markdown]
# Алгоритм принятия дз
# 1) чекаем дз в тг
# 2) зайти в кошечку и нажать fetch origin
# 3) fork - клонирование чужого репозитория в личный гитхаб
# 4) отправка дз в кошке - написать название коммита
# 5) нажимаем commit to main  пуш синяя

# %% [markdown]
# ![0DFA2D9E-C98F-472E-84B4-62E27C7389E7.jpeg](attachment:0DFA2D9E-C98F-472E-84B4-62E27C7389E7.jpeg)

# %% [markdown]
# ![AD41D478-3210-41D7-B392-959106C3A367.jpeg](attachment:AD41D478-3210-41D7-B392-959106C3A367.jpeg)

# %% [markdown]
# ![ ](attachment:AD41D478-3210-41D7-B392-959106C3A367.jpeg)

# %% [markdown]
# ![291BB430-4335-472D-B806-020BCFEED4DF.jpeg](attachment:291BB430-4335-472D-B806-020BCFEED4DF.jpeg)

# %%
1 + 1
# Out:
# 2

# %%
pre-commit run --all-files #linter files
