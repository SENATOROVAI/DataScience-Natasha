# %%
"""Модуль посвящен третьему уроку.

В данном модуле рассматривали работу с 
интерпретатор и CPython.
"""
# Out:
# 'Модуль посвящен первому уроку.\n\nВ данном модуле рассматривали работу с \nгитхаб и кэгл.\n'

# %% [markdown]
# Компилятор преобразует весь исходный код в машинный код за один раз, что ускоряет процесс. Интерпретатор выполняет код построчно. Интерпретатор - компьютерная программа, которая непосредственно выполняет инструкции, написанные на каком-либо языке программирования. В моем случае используется СPython - стандартная и наиболее широко используемая реализация языка программирования Python. Python - язык программирования с открытым кодом. С - 35,0% данного языка программирования использовано для создания СPython, 62,8% - Python.  С -  используемые инструкции для Python, Python - оболочка, код написан на С. .h - расширение для C  и C++. Весь код CPython можно найти на гитхабе, все проекты, созданные специалистами, нможно найти там же. Научилась использовать Explorer на компьютере: Finder - переход - переход к папке - свойства - где находится.
