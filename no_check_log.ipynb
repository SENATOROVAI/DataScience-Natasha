# %%
"""Модуль посвящен четвертому уроку.

В данном модуле рассматривали суть интерпретатора Pypy.
"""
# Out:
# 'Модуль посвящен четвертому уроку.\n\nВ данном модуле рассматривали суть интерпретатора Pypy.\n'

# %% [markdown]
# Интерпретатор - это программа, которая выполняет код, написанный на языке программирования. К ним относятся CPython и Pypy. Pypy - недавно разработанный интерпретатор, отличающийся более высокой скоростью работы по сравнению с другими интерпретаторами, однако он совместим не со всеми проектами. Всю документацию по нему можно найти на официальном сайте. Для того, чтобы открыть файл через интерпретатор, нужно в терминале сначала обратиться к интерпретатору, введя его месторасположение, а затем обратиться  к самому текстовому файлу, также введя его месторасположение (t + tab).  Файл .exe - файл с исполняемым кодом программы. Открыв его, можно узнать версию интерпретатора и версию Python  в нем.
