# %%
"""Модуль посвящен уроку по теории вероятности."""
# Out:
# 'Модуль посвящен уроку по теории вероятности.'

# %% [markdown]
# 05.08
#
# Изучила понятие 'вероятность события' - количественная мера наступления события в результате испытания. Обозначается 'P' (или p), событие берется в скобки, выступая в в роли аргумента. Изучила способ оформления функции в Python. Используются простые дроби для решения задач либо десятичные с округлением до 4 знака. Сумма вероятностей событий, которые образуют полную группу равна единице. Поную группу могут образовывать противоположные события. События равновозможны, их вероятности одинаковы. Теорема также справедлива в элементарных исходах и их вероятностях.

# %% [markdown]
# 08.08
#
# 1. Начали изучать основы комбинаторики
# 2. Прошли формулу количества перестановок
# 3. Прошли формулу количества сочетаний
# 4. Изучили три формулы количества сочетаний, в которых k = 0, 1 или k  и n имеют равные значения
# 5. Изучили формулу размещений, она может быть представлена в виде произведения формулы сочетаний и перестановок

# %% [markdown]
# 03.09
#
# 1. Прошли теорему сложения вероятностей несовместных событий
# 2. Вероятность появления одного из двух несовместных событий(без разницы, какого) равна сумме вероятностей этих событий
# 3. Рассмотрели алгебру событий
# 4. Для совместных событий равенство P(A+B)=P(A)+P(B) будет неверным
# 5. По теореме сложения вероятностей событий P(B1+B2) = P(B1)+P(B2)
# 6. Решили задачи с использованием теоремы сложения вероятностей событий

# %% [markdown]
# 17.09.
#
# 1. Составила резюме на HeadHunter
# 2. Определила список возможных должностей при трудоустройстве
# 3. Научилась искать вакансии по ключевым словам:
# 4. Изучила понятие JSON

# %% [markdown]
# 21.09
#
# 1. Изучила понятия зависимого и независимого события
# 2. Прошла теорему умножения вероятностей независимых событий
# 3. Изучила понятие "дополнения к событию"
# 4. Решила задачи на теоремы сложения  и умножения вероятностей независимых событий

# %% [markdown]
# 8.10
#
# 1. Удалила ветку на гитхаб
# 2. Использовала команды в терминале

# %% [markdown]
# 12.10
#
# 1. Прошла теорему умножения вероятностей зависимых событий
# 2. Решала задачи по теме умножения вероятностей зависимых собыйтий
# 3. Подлючила домен США
# 4. Изучила правила пользования Canva.com

# %% [markdown]
# 19.10
#
# 1. Изучила формулу полной вероятности
# 2. Изучила формулу Байеса
# 3. Решала задачи на формулу полной вероятности и формулу Байеса
