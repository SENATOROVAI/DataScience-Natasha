# %%
"""Модуль посвящен пятому уроку.

В данном модуле рассматривали теорию веороятности.
"""
# Out:
# 'Модуль посвящен пятому уроку.\n\nВ данном модуле рассматривали теорию веороятности.\n'

# %% [markdown]
# Через метод Монте-Карло можно смоделировать генерацию случайных величин. События могут быть достоверными, невозможными и случайными. Исход - любой результат испытания. События обозначают большими латинскими буквами с подстрочными индексами, избегая буквы "P". Равновозможные события - ни одно из них не является более возможным, чем другое. События также могут быть неравновозможными. Несовместные события - в одном и том же испытании появление одного из событий исключает появление других. Противоположное событие обозначается черточкой наверху. Множество несовместных событий образуют полную группу, если в результате отдельно взятого испытания обязательно появится одно и только одно из этих событий. Также есть элементарное событие, его нельзя разложить на другие события. События можно сложить (или) и умножить(и).
